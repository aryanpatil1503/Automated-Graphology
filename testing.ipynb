# %%
import os

# %%
import extract

# %%
os.chdir("C:\\Users\\aryan\\Desktop\\TE SEM5\\Seminar\\project\\virtual_env\\train")
files = [f for f in os.listdir('.') if os.path.isfile(f)]
os.chdir("..")

# %%
print(files)
# Out:
# ['a01-000u-s00-00.png', 'a01-000u-s00-01.png', 'a01-000u-s00-02.png', 'a01-000u-s00-03.png', 'a01-000u-s01-00.png', 'a01-000u-s01-01.png', 'a01-000u-s01-02.png', 'a01-000u-s01-03.png', 'a01-003u-s00-00.png', 'a01-003u-s00-01.png', 'a01-003u-s00-02.png', 'a01-003u-s00-03.png', 'a01-003u-s01-00.png', 'a01-003u-s01-01.png', 'a01-003u-s01-02.png', 'a01-003u-s01-03.png', 'a01-003u-s01-04.png', 'a01-003u-s02-00.png', 'a01-003u-s02-01.png', 'a01-003u-s02-02.png', 'a01-003u-s02-03.png', 'a01-007u-s00-00.png', 'a01-007u-s00-01.png', 'a01-007u-s01-00.png', 'a01-007u-s01-01.png', 'a01-007u-s01-02.png', 'a01-007u-s01-03.png', 'a01-007u-s01-04.png', 'a01-007u-s02-00.png', 'a01-007u-s02-01.png', 'a01-007u-s02-02.png', 'a01-007u-s02-03.png', 'a01-007u-s02-04.png', 'a01-011u-s00-00.png', 'a01-011u-s00-01.png', 'a01-011u-s00-02.png', 'a01-011u-s00-03.png', 'a01-011u-s00-04.png', 'a01-011u-s00-05.png', 'a01-011u-s01-00.png', 'a01-011u-s01-01.png', 'a01-011u-s01-02.png', 'a01-011u-s01-03.png', 'a01-011
# ...

# %%
page_ids = []

# %%
with open("raw_feature_list3", "a") as label:
    count = len(page_ids)
    for file_name in files:
        if(file_name in page_ids):
            continue
        features = extract.start(file_name)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-43-f5639e6d88c4> in <module>
#       4         if(file_name in page_ids):
#       5             continue
# ----> 6         features = extract.start(file_name)
#
# c:\Users\aryan\Desktop\TE SEM5\Seminar\project\virtual_env\extract.py in start(file_name)
#     828         "train/"+file_name)
#     829     # cv2.imshow(file_name,image)
# --> 830
#     831     # Extract pen pressure. It's such a cool function name!
#     832     barometer(image)
#
# c:\Users\aryan\Desktop\TE SEM5\Seminar\project\virtual_env\extract.py in barometer(image)
#     774
#     775     # it's extremely necessary to convert to grayscale first
# --> 776     #img = cv2.imread(image)
#     777     image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# ...

# %%
import cv2

# %%
a='g06-026h-s01-00.png'
img = cv2.imread('C:\\Users\\aryan\\Desktop\\TE SEM5\\Seminar\\project\\train\\'+a)

# %%
image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
